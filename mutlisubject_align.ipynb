# %%
import numpy as np
import scipy
import scipy.io as sio
import matplotlib.pyplot as plt
import nibabel as nib

import os
from os.path import join as opj
from os.path import join, exists, split
import time
import urllib.request
import warnings
from tqdm import tqdm
from pprint import pprint
import zipfile
import glob
warnings.filterwarnings('ignore')
from transformers import AutoFeatureExtractor, ClapModel
import torch
import torchaudio

from sklearn.linear_model import LogisticRegression, RidgeCV, Ridge
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder


import pandas as pd
from nilearn import maskers
from nilearn import plotting
import tqdm

from nilearn.glm.first_level import FirstLevelModel
from nilearn.image import concat_imgs, mean_img
import matplotlib.pyplot as plt
import nilearn
from nilearn.plotting import plot_design_matrix
from nilearn.plotting import plot_contrast_matrix
from importlib import reload # python 2.7 does not require this
import data
reload(data)
from data import load_data
import pickle
from nltools.data import Brain_Data, Adjacency
from nltools.stats import align

import seaborn as sns
import IPython.display as ipd
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ## LAVORARE QUA, NEL DICT working_data_subj_avg ho sempre gli stessi dati forse devo rinannare il codice e controllare

# %%
# %pip install nltools

# %%
data_dict = {}

# %%
transform_masking=True
subject_ids = ["sub-001", "sub-002", "sub-003", "sub-004", "sub-005"]

# %%
load_cache=False

if not load_cache:
    # Initialize an empty dictionary to store the data
    mask=True

    # Loop over each subject ID
    for subject_id in subject_ids:

        print("[INFO] Analyzing sub", subject_id)
        # Load data for the current subject
        train_fmri_avg,train_audio_feat,train_genre,train_audio,test_fmri_avg,test_audio_feat,test_genre,test_audio, masker,train_stim_name, test_stim_name   = load_data(subject_id,mask)

        # Store the data in the dictionary
        data_dict[subject_id] = {
            "train_fmri": train_fmri_avg,
            "train_audio_feat": train_audio_feat,
            "train_genre": train_genre,
            "train_audio": train_audio,
            "test_fmri": test_fmri_avg,
            "test_audio_feat": test_audio_feat,
            "test_genre": test_genre,
            "test_audio" : test_audio,
            "masker": masker,
            "train_stim_name": train_stim_name, 
            "test_stim_name": test_stim_name
        }
# Out:
# [INFO] Analyzing sub sub-001
#   0%|          | 0/18 [00:00<?, ?it/s]
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Test_run-01_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Test_run-03_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Test_run-02_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Test_run-04_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Training_run-03_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Test_run-06_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Training_run-02_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Training_run-06_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Training_run-07_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Training_run-05_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# 100%|██████████| 18/18 [00:01<00:00, 15.34it/s]
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Training_run-09_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Training_run-04_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Test_run-05_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Training_run-10_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Training_run-11_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Training_run-12_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Training_run-01_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Training_run-08_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# Masking files..
# 100%|██████████| 18/18 [03:59<00:00, 13.29s/it]
# (237653, 410)
# (237653, 410)
# (237653, 410)
# (237653, 410)
# (237653, 410)
# (237653, 410)
# (237653, 410)
# (237653, 410)
# (237653, 410)
# (237653, 410)
# (237653, 410)
# (237653, 410)
# (237653, 410)
# (237653, 410)
# (237653, 410)
# (237653, 410)
# (237653, 410)
# (237653, 410)
# Loading nifti and events..
# 100%|██████████| 18/18 [00:00<00:00, 633.22it/s]
# Detrending fMRI data..
# Preparing dataset..
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Test_run-01_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Test_run-03_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Test_run-02_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Test_run-04_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Training_run-03_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Test_run-06_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Training_run-02_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Training_run-06_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Training_run-07_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Training_run-05_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Training_run-09_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Training_run-04_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Test_run-05_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Training_run-10_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Training_run-11_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Training_run-12_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Training_run-01_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-001/func/sub-001_task-Training_run-08_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# 100%|██████████| 492/492 [00:00<00:00, 946.51it/s]
# 100%|██████████| 246/246 [00:00<00:00, 971.63it/s]
# Audio feature extraction...
# 492it [03:10,  2.58it/s]
# 246it [01:32,  2.66it/s]
# [INFO] Analyzing sub sub-002
# 100%|██████████| 18/18 [00:00<00:00, 410.06it/s]
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Test_run-01_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Test_run-03_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Test_run-06_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Test_run-05_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Training_run-11_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Training_run-06_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Test_run-04_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Training_run-12_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Test_run-02_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Training_run-01_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Training_run-09_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Training_run-08_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Training_run-04_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Training_run-07_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Training_run-10_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Training_run-02_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Training_run-05_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Training_run-03_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# Masking files..
# 100%|██████████| 18/18 [03:24<00:00, 11.36s/it]
# (230762, 410)
# (230762, 410)
# (230762, 410)
# (230762, 410)
# (230762, 410)
# (230762, 410)
# (230762, 410)
# (230762, 410)
# (230762, 410)
# (230762, 410)
# (230762, 410)
# (230762, 410)
# (230762, 410)
# (230762, 410)
# (230762, 410)
# (230762, 410)
# (230762, 410)
# (230762, 410)
# Loading nifti and events..
# 100%|██████████| 18/18 [00:00<00:00, 680.96it/s]
# Detrending fMRI data..
# Preparing dataset..
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Test_run-01_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Test_run-03_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Test_run-06_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Test_run-05_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Training_run-11_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Training_run-06_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Test_run-04_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Training_run-12_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Test_run-02_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Training_run-01_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Training_run-09_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Training_run-08_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Training_run-04_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Training_run-07_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Training_run-10_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Training_run-02_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Training_run-05_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-002/func/sub-002_task-Training_run-03_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# 100%|██████████| 492/492 [00:00<00:00, 997.37it/s]
# 100%|██████████| 246/246 [00:00<00:00, 846.85it/s]
# Audio feature extraction...
# 492it [04:45,  1.72it/s]
# 246it [01:36,  2.56it/s]
# [INFO] Analyzing sub sub-003
# 100%|██████████| 18/18 [00:00<00:00, 493.67it/s]
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Test_run-03_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Test_run-01_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Test_run-05_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Test_run-06_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Test_run-02_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Training_run-02_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Training_run-03_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Training_run-05_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Training_run-06_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Training_run-08_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Training_run-07_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Test_run-04_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Training_run-09_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Training_run-04_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Training_run-10_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Training_run-11_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Training_run-12_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Training_run-01_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# Masking files..
# 100%|██████████| 18/18 [02:43<00:00,  9.10s/it]
# (229190, 410)
# (229190, 410)
# (229190, 410)
# (229190, 410)
# (229190, 410)
# (229190, 410)
# (229190, 410)
# (229190, 410)
# (229190, 410)
# (229190, 410)
# (229190, 410)
# (229190, 410)
# (229190, 410)
# (229190, 410)
# (229190, 410)
# (229190, 410)
# (229190, 410)
# (229190, 410)
# Loading nifti and events..
# 100%|██████████| 18/18 [00:00<00:00, 700.95it/s]
# Detrending fMRI data..
# Preparing dataset..
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Test_run-03_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Test_run-01_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Test_run-05_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Test_run-06_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Test_run-02_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Training_run-02_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Training_run-03_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Training_run-05_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Training_run-06_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Training_run-08_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Training_run-07_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Test_run-04_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Training_run-09_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Training_run-04_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Training_run-10_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Training_run-11_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Training_run-12_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-003/func/sub-003_task-Training_run-01_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# 100%|██████████| 492/492 [00:00<00:00, 814.59it/s]
# 100%|██████████| 246/246 [00:00<00:00, 1069.62it/s]
# Audio feature extraction...
# 492it [03:11,  2.56it/s]
# 246it [01:35,  2.58it/s]
# [INFO] Analyzing sub sub-004
# 100%|██████████| 18/18 [00:00<00:00, 282.91it/s]
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Test_run-02_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Test_run-01_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Test_run-04_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Test_run-03_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Test_run-06_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Test_run-05_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Training_run-03_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Training_run-02_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Training_run-04_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Training_run-08_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Training_run-07_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Training_run-01_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Training_run-09_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Training_run-06_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Training_run-12_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Training_run-10_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Training_run-11_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Training_run-05_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# Masking files..
# 100%|██████████| 18/18 [02:43<00:00,  9.11s/it]
# (216424, 410)
# (216424, 410)
# (216424, 410)
# (216424, 410)
# (216424, 410)
# (216424, 410)
# (216424, 410)
# (216424, 410)
# (216424, 410)
# (216424, 410)
# (216424, 410)
# (216424, 410)
# (216424, 410)
# (216424, 410)
# (216424, 410)
# (216424, 410)
# (216424, 410)
# (216424, 410)
# Loading nifti and events..
# 100%|██████████| 18/18 [00:00<00:00, 617.39it/s]
# Detrending fMRI data..
# Preparing dataset..
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Test_run-02_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Test_run-01_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Test_run-04_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Test_run-03_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Test_run-06_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Test_run-05_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Training_run-03_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Training_run-02_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Training_run-04_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Training_run-08_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Training_run-07_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Training_run-01_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Training_run-09_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Training_run-06_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Training_run-12_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Training_run-10_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Training_run-11_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-004/func/sub-004_task-Training_run-05_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# 100%|██████████| 492/492 [00:00<00:00, 993.05it/s]
# 100%|██████████| 246/246 [00:00<00:00, 922.58it/s]
# Audio feature extraction...
# 492it [03:09,  2.60it/s]
# 246it [01:33,  2.62it/s]
# [INFO] Analyzing sub sub-005
# 100%|██████████| 18/18 [00:00<00:00, 333.57it/s]
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Test_run-01_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Test_run-02_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Test_run-03_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Training_run-01_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Test_run-05_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Test_run-04_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Training_run-05_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Training_run-06_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Training_run-04_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Training_run-09_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Training_run-07_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Training_run-03_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Training_run-11_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Training_run-10_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Training_run-12_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Training_run-02_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Test_run-06_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Training_run-08_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# Masking files..
# 100%|██████████| 18/18 [02:56<00:00,  9.78s/it]
# (222789, 410)
# (222789, 410)
# (222789, 410)
# (222789, 410)
# (222789, 410)
# (222789, 410)
# (222789, 410)
# (222789, 410)
# (222789, 410)
# (222789, 410)
# (222789, 410)
# (222789, 410)
# (222789, 410)
# (222789, 410)
# (222789, 410)
# (222789, 410)
# (222789, 410)
# (222789, 410)
# Loading nifti and events..
# 100%|██████████| 18/18 [00:00<00:00, 242.61it/s]
# Detrending fMRI data..
# Preparing dataset..
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Test_run-01_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Test_run-02_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Test_run-03_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Training_run-01_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Test_run-05_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Test_run-04_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Training_run-05_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Training_run-06_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Training_run-04_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Training_run-09_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Training_run-07_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Training_run-03_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Training_run-11_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Training_run-10_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Training_run-12_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Training_run-02_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Test_run-06_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# /data01/data/fMRI_music_genre/ds003720-download/derivatives/sub-005/func/sub-005_task-Training_run-08_space-MNI152NLin2009cAsym_desc-preproc_bold.nii.gz
# 100%|██████████| 492/492 [00:00<00:00, 668.46it/s]
# 100%|██████████| 246/246 [00:00<00:00, 654.58it/s]
# Audio feature extraction...
# 492it [04:17,  1.91it/s]
# 246it [01:35,  2.57it/s]

# %%
# with open('/data01/data/fMRI_music_genre/data_dict' + '.pkl', 'wb') as file_to_write:
#     pickle.dump(data_dict, file_to_write, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('/data01/data/fMRI_music_genre/data_dict' + '.pkl', 'rb') as file_to_read:
    data_dict = pickle.load(file_to_read)

# %%
print(data_dict['sub-001']['train_audio_feat'].shape)
print(data_dict['sub-001']['train_fmri'].shape)
print(data_dict['sub-002']['train_audio_feat'].shape)
print(data_dict['sub-002']['train_fmri'].shape)
print(len(data_dict['sub-001']['train_genre']))
print(len(data_dict['sub-001']['train_stim_name']))
print(data_dict['sub-001']['test_audio_feat'].shape)
print(data_dict['sub-001']['test_fmri'].shape)
print(len(data_dict['sub-001']['test_genre']))
print(len(data_dict['sub-001']['test_stim_name']))
# Out:
# torch.Size([492, 512])
# torch.Size([492, 237653])
# torch.Size([492, 512])
# torch.Size([492, 230762])
# 492
# 492
# torch.Size([246, 512])
# torch.Size([246, 237653])
# 246
# 246

# %%
def load_transformed_data(data_folder):
    # Initialize an empty dictionary to store the data
    loaded_data_dict = {}

    # Loop through all files in the data folder
    for filename in os.listdir(data_folder):
        # Construct the full path of the file
        file_path = os.path.join(data_folder, filename)
        
        # Extract the subject ID and key from the filename
        # Assuming filenames are in the format 'sub_key.ext'
        sub, key = filename.split('_', 1)
        key = key.rsplit('.', 1)[0]  # Removes extension part to get the key
        
        #repeat
        key = key.rsplit('.', 1)[0]  # Removes extension part to get the key

        # Initialize sub dictionary if it doesn't exist
        if sub not in loaded_data_dict:
            loaded_data_dict[sub] = {}

        # Determine the file type and load accordingly
        if filename.endswith('.npy'):
            loaded_data_dict[sub][key] = np.load(file_path)
        elif filename.endswith('.pkl'):
            with open(file_path, 'rb') as file:
                loaded_data_dict[sub][key] = pickle.load(file)

        print(f"Loaded {key} from {file_path}")

    return loaded_data_dict

# %%
#RESET masking to the same number of voxels

if transform_masking:
    working_data_dict = data_dict.copy()
    base_masker=working_data_dict["sub-001"]["masker"]
    for sub in subject_ids:

        x_tr=working_data_dict[sub]["train_fmri"]
        x_ts=working_data_dict[sub]["test_fmri"]
        masker = working_data_dict[sub]["masker"]

        x_tr_list=[]
        for x in tqdm.tqdm(x_tr):
            #undo masking

            tmp = masker.inverse_transform(x)
            x_tr_list.append(base_masker.transform(tmp))

        x_tr = torch.tensor(np.stack(x_tr_list))


        x_ts_list=[]
        for x in tqdm.tqdm(x_ts):
            tmp = masker.inverse_transform(x)
            x_ts_list.append(base_masker.transform(tmp))

        #undo masking
        x_ts = torch.tensor(np.stack(x_ts_list))
        working_data_dict[sub]["train_fmri"] = x_tr
        working_data_dict[sub]["test_fmri"] = x_ts
# Out:
# 100%|██████████| 492/492 [05:23<00:00,  1.52it/s]
# 100%|██████████| 246/246 [02:39<00:00,  1.54it/s]
# 100%|██████████| 492/492 [06:18<00:00,  1.30it/s]
# 100%|██████████| 246/246 [03:10<00:00,  1.29it/s]
# 100%|██████████| 492/492 [05:44<00:00,  1.43it/s]
# 100%|██████████| 246/246 [02:25<00:00,  1.69it/s]
# 100%|██████████| 492/492 [05:05<00:00,  1.61it/s]
# 100%|██████████| 246/246 [02:30<00:00,  1.63it/s]
# 100%|██████████| 492/492 [04:55<00:00,  1.67it/s]
# 100%|██████████| 246/246 [02:34<00:00,  1.60it/s]

# %%
# with open('/data01/data/fMRI_music_genre/working_data_dict' + '.pkl', 'wb') as file_to_write:
#     pickle.dump(working_data_dict, file_to_write, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('/data01/data/fMRI_music_genre/working_data_dict' + '.pkl', 'rb') as file_to_read:
    working_data_dict = pickle.load(file_to_read)

# %%
if transform_masking:
    base_masker=working_data_dict["sub-001"]["masker"]
    selected_indices=base_masker.transform(nib.load("mask_01.nii.gz"))
    for sub in subject_ids:
        working_data_dict[sub]["train_fmri_avg"]=working_data_dict[sub]["train_fmri"].squeeze()[:,selected_indices.squeeze().astype(np.uint8)]
        working_data_dict[sub]["test_fmri_avg"]=working_data_dict[sub]["test_fmri"].squeeze()[:,selected_indices.squeeze().astype(np.uint8)]

# %%
working_data_dict[sub].keys()
# Out:
# dict_keys(['train_fmri', 'train_audio_feat', 'train_genre', 'train_audio', 'test_fmri', 'test_audio_feat', 'test_genre', 'test_audio', 'masker', 'train_stim_name', 'test_stim_name', 'train_fmri_avg', 'test_fmri_avg'])

# %%
if transform_masking:

    # Ensure the data directory exists
    data_folder = 'data'
    os.makedirs(data_folder, exist_ok=True)

    # Assuming working_data_dict is your main dictionary and 'sub' is defined
    for sub in subject_ids:
        for key, value in working_data_dict[sub].items():
            # Convert the value to a numpy array if it's not already one 
            print(key)

            # Define the path for the output file
            file_path = os.path.join(data_folder, f'{sub}_{key}.npy')

            # Check if the value is a numpy array
            if isinstance(value, np.ndarray):
                # Save the numpy array to a file with .npy extension
                np.save(file_path + '.npy', value)
                print(f"Saved {key} as an array to {file_path}.npy")
            else:
                # Save other types of data using pickle with .pkl extension
                with open(file_path + '.pkl', 'wb') as file:
                    pickle.dump(value, file, protocol=pickle.HIGHEST_PROTOCOL)
                print(f"Saved {key} using pickle to {file_path}.pkl")

            print(f"Saved {key} to {file_path}")

        
else:
    # Use the function
    data_folder = 'data'  # Specify the data folder path
    working_data_dict = load_transformed_data(data_folder)
# Out:
# train_fmri
# Saved train_fmri using pickle to data/sub-001_train_fmri.npy.pkl
# Saved train_fmri to data/sub-001_train_fmri.npy
# train_audio_feat
# Saved train_audio_feat using pickle to data/sub-001_train_audio_feat.npy.pkl
# Saved train_audio_feat to data/sub-001_train_audio_feat.npy
# train_genre
# Saved train_genre using pickle to data/sub-001_train_genre.npy.pkl
# Saved train_genre to data/sub-001_train_genre.npy
# train_audio
# Saved train_audio using pickle to data/sub-001_train_audio.npy.pkl
# Saved train_audio to data/sub-001_train_audio.npy
# test_fmri
# Saved test_fmri using pickle to data/sub-001_test_fmri.npy.pkl
# Saved test_fmri to data/sub-001_test_fmri.npy
# test_audio_feat
# Saved test_audio_feat using pickle to data/sub-001_test_audio_feat.npy.pkl
# Saved test_audio_feat to data/sub-001_test_audio_feat.npy
# test_genre
# Saved test_genre using pickle to data/sub-001_test_genre.npy.pkl
# Saved test_genre to data/sub-001_test_genre.npy
# test_audio
# Saved test_audio using pickle to data/sub-001_test_audio.npy.pkl
# Saved test_audio to data/sub-001_test_audio.npy
# masker
# Saved masker using pickle to data/sub-001_masker.npy.pkl
# Saved masker to data/sub-001_masker.npy
# train_stim_name
# Saved train_stim_name using pickle to data/sub-001_train_stim_name.npy.pkl
# Saved train_stim_name to data/sub-001_train_stim_name.npy
# test_stim_name
# Saved test_stim_name using pickle to data/sub-001_test_stim_name.npy.pkl
# Saved test_stim_name to data/sub-001_test_stim_name.npy
# train_fmri_avg
# Saved train_fmri_avg using pickle to data/sub-001_train_fmri_avg.npy.pkl
# Saved train_fmri_avg to data/sub-001_train_fmri_avg.npy
# test_fmri_avg
# Saved test_fmri_avg using pickle to data/sub-001_test_fmri_avg.npy.pkl
# Saved test_fmri_avg to data/sub-001_test_fmri_avg.npy
# train_fmri
# Saved train_fmri using pickle to data/sub-002_train_fmri.npy.pkl
# Saved train_fmri to data/sub-002_train_fmri.npy
# train_audio_feat
# Saved train_audio_feat using pickle to data/sub-002_train_audio_feat.npy.pkl
# Saved train_audio_feat to data/sub-002_train_audio_feat.npy
# train_genre
# Saved train_genre using pickle to data/sub-002_train_genre.npy.pkl
# Saved train_genre to data/sub-002_train_genre.npy
# train_audio
# Saved train_audio using pickle to data/sub-002_train_audio.npy.pkl
# Saved train_audio to data/sub-002_train_audio.npy
# test_fmri
# Saved test_fmri using pickle to data/sub-002_test_fmri.npy.pkl
# Saved test_fmri to data/sub-002_test_fmri.npy
# test_audio_feat
# Saved test_audio_feat using pickle to data/sub-002_test_audio_feat.npy.pkl
# Saved test_audio_feat to data/sub-002_test_audio_feat.npy
# test_genre
# Saved test_genre using pickle to data/sub-002_test_genre.npy.pkl
# Saved test_genre to data/sub-002_test_genre.npy
# test_audio
# Saved test_audio using pickle to data/sub-002_test_audio.npy.pkl
# Saved test_audio to data/sub-002_test_audio.npy
# masker
# Saved masker using pickle to data/sub-002_masker.npy.pkl
# Saved masker to data/sub-002_masker.npy
# train_stim_name
# Saved train_stim_name using pickle to data/sub-002_train_stim_name.npy.pkl
# Saved train_stim_name to data/sub-002_train_stim_name.npy
# test_stim_name
# Saved test_stim_name using pickle to data/sub-002_test_stim_name.npy.pkl
# Saved test_stim_name to data/sub-002_test_stim_name.npy
# train_fmri_avg
# Saved train_fmri_avg using pickle to data/sub-002_train_fmri_avg.npy.pkl
# Saved train_fmri_avg to data/sub-002_train_fmri_avg.npy
# test_fmri_avg
# Saved test_fmri_avg using pickle to data/sub-002_test_fmri_avg.npy.pkl
# Saved test_fmri_avg to data/sub-002_test_fmri_avg.npy
# train_fmri
# Saved train_fmri using pickle to data/sub-003_train_fmri.npy.pkl
# Saved train_fmri to data/sub-003_train_fmri.npy
# train_audio_feat
# Saved train_audio_feat using pickle to data/sub-003_train_audio_feat.npy.pkl
# Saved train_audio_feat to data/sub-003_train_audio_feat.npy
# train_genre
# Saved train_genre using pickle to data/sub-003_train_genre.npy.pkl
# Saved train_genre to data/sub-003_train_genre.npy
# train_audio
# Saved train_audio using pickle to data/sub-003_train_audio.npy.pkl
# Saved train_audio to data/sub-003_train_audio.npy
# test_fmri
# Saved test_fmri using pickle to data/sub-003_test_fmri.npy.pkl
# Saved test_fmri to data/sub-003_test_fmri.npy
# test_audio_feat
# Saved test_audio_feat using pickle to data/sub-003_test_audio_feat.npy.pkl
# Saved test_audio_feat to data/sub-003_test_audio_feat.npy
# test_genre
# Saved test_genre using pickle to data/sub-003_test_genre.npy.pkl
# Saved test_genre to data/sub-003_test_genre.npy
# test_audio
# Saved test_audio using pickle to data/sub-003_test_audio.npy.pkl
# Saved test_audio to data/sub-003_test_audio.npy
# masker
# Saved masker using pickle to data/sub-003_masker.npy.pkl
# Saved masker to data/sub-003_masker.npy
# train_stim_name
# Saved train_stim_name using pickle to data/sub-003_train_stim_name.npy.pkl
# Saved train_stim_name to data/sub-003_train_stim_name.npy
# test_stim_name
# Saved test_stim_name using pickle to data/sub-003_test_stim_name.npy.pkl
# Saved test_stim_name to data/sub-003_test_stim_name.npy
# train_fmri_avg
# Saved train_fmri_avg using pickle to data/sub-003_train_fmri_avg.npy.pkl
# Saved train_fmri_avg to data/sub-003_train_fmri_avg.npy
# test_fmri_avg
# Saved test_fmri_avg using pickle to data/sub-003_test_fmri_avg.npy.pkl
# Saved test_fmri_avg to data/sub-003_test_fmri_avg.npy
# train_fmri
# Saved train_fmri using pickle to data/sub-004_train_fmri.npy.pkl
# Saved train_fmri to data/sub-004_train_fmri.npy
# train_audio_feat
# Saved train_audio_feat using pickle to data/sub-004_train_audio_feat.npy.pkl
# Saved train_audio_feat to data/sub-004_train_audio_feat.npy
# train_genre
# Saved train_genre using pickle to data/sub-004_train_genre.npy.pkl
# Saved train_genre to data/sub-004_train_genre.npy
# train_audio
# Saved train_audio using pickle to data/sub-004_train_audio.npy.pkl
# Saved train_audio to data/sub-004_train_audio.npy
# test_fmri
# Saved test_fmri using pickle to data/sub-004_test_fmri.npy.pkl
# Saved test_fmri to data/sub-004_test_fmri.npy
# test_audio_feat
# Saved test_audio_feat using pickle to data/sub-004_test_audio_feat.npy.pkl
# Saved test_audio_feat to data/sub-004_test_audio_feat.npy
# test_genre
# Saved test_genre using pickle to data/sub-004_test_genre.npy.pkl
# Saved test_genre to data/sub-004_test_genre.npy
# test_audio
# Saved test_audio using pickle to data/sub-004_test_audio.npy.pkl
# Saved test_audio to data/sub-004_test_audio.npy
# masker
# Saved masker using pickle to data/sub-004_masker.npy.pkl
# Saved masker to data/sub-004_masker.npy
# train_stim_name
# Saved train_stim_name using pickle to data/sub-004_train_stim_name.npy.pkl
# Saved train_stim_name to data/sub-004_train_stim_name.npy
# test_stim_name
# Saved test_stim_name using pickle to data/sub-004_test_stim_name.npy.pkl
# Saved test_stim_name to data/sub-004_test_stim_name.npy
# train_fmri_avg
# Saved train_fmri_avg using pickle to data/sub-004_train_fmri_avg.npy.pkl
# Saved train_fmri_avg to data/sub-004_train_fmri_avg.npy
# test_fmri_avg
# Saved test_fmri_avg using pickle to data/sub-004_test_fmri_avg.npy.pkl
# Saved test_fmri_avg to data/sub-004_test_fmri_avg.npy
# train_fmri
# Saved train_fmri using pickle to data/sub-005_train_fmri.npy.pkl
# Saved train_fmri to data/sub-005_train_fmri.npy
# train_audio_feat
# Saved train_audio_feat using pickle to data/sub-005_train_audio_feat.npy.pkl
# Saved train_audio_feat to data/sub-005_train_audio_feat.npy
# train_genre
# Saved train_genre using pickle to data/sub-005_train_genre.npy.pkl
# Saved train_genre to data/sub-005_train_genre.npy
# train_audio
# Saved train_audio using pickle to data/sub-005_train_audio.npy.pkl
# Saved train_audio to data/sub-005_train_audio.npy
# test_fmri
# Saved test_fmri using pickle to data/sub-005_test_fmri.npy.pkl
# Saved test_fmri to data/sub-005_test_fmri.npy
# test_audio_feat
# Saved test_audio_feat using pickle to data/sub-005_test_audio_feat.npy.pkl
# Saved test_audio_feat to data/sub-005_test_audio_feat.npy
# test_genre
# Saved test_genre using pickle to data/sub-005_test_genre.npy.pkl
# Saved test_genre to data/sub-005_test_genre.npy
# test_audio
# Saved test_audio using pickle to data/sub-005_test_audio.npy.pkl
# Saved test_audio to data/sub-005_test_audio.npy
# masker
# Saved masker using pickle to data/sub-005_masker.npy.pkl
# Saved masker to data/sub-005_masker.npy
# train_stim_name
# Saved train_stim_name using pickle to data/sub-005_train_stim_name.npy.pkl
# Saved train_stim_name to data/sub-005_train_stim_name.npy
# test_stim_name
# Saved test_stim_name using pickle to data/sub-005_test_stim_name.npy.pkl
# Saved test_stim_name to data/sub-005_test_stim_name.npy
# train_fmri_avg
# Saved train_fmri_avg using pickle to data/sub-005_train_fmri_avg.npy.pkl
# Saved train_fmri_avg to data/sub-005_train_fmri_avg.npy
# test_fmri_avg
# Saved test_fmri_avg using pickle to data/sub-005_test_fmri_avg.npy.pkl
# Saved test_fmri_avg to data/sub-005_test_fmri_avg.npy

# %%
torch.equal(working_data_dict["sub-001"]["train_fmri"],working_data_dict["sub-002"]["train_fmri"])
# Out:
# False

# %%
## check if genre sequences are the same

for sub in subject_ids:
    print(working_data_dict[sub]["train_fmri"].shape)
    print()
    print(working_data_dict[sub]["test_fmri"].shape)
# Out:
# torch.Size([492, 1, 237653])
#
# torch.Size([246, 1, 237653])
# torch.Size([492, 1, 237653])
#
# torch.Size([246, 1, 237653])
# torch.Size([492, 1, 237653])
#
# torch.Size([246, 1, 237653])
# torch.Size([492, 1, 237653])
#
# torch.Size([246, 1, 237653])
# torch.Size([492, 1, 237653])
#
# torch.Size([246, 1, 237653])

# %%
## TO DO 

# find duplicates in training set, average their activity.

# find duplicates in test set, average their activity

# match indices in training and test dataset across subject, sort data

# do functional alignment

# %%
print(working_data_dict['sub-001']['train_audio_feat'].shape)
print(working_data_dict['sub-001']['train_fmri'].shape)
print(working_data_dict['sub-001']['train_fmri_avg'].shape)
print(len(working_data_dict['sub-001']['train_genre']))
print(len(working_data_dict['sub-001']['train_stim_name']))
print(working_data_dict['sub-001']['test_audio_feat'].shape)
print(working_data_dict['sub-001']['test_fmri'].shape)
print(working_data_dict['sub-001']['test_fmri_avg'].shape)
print(len(working_data_dict['sub-001']['test_genre']))
print(len(working_data_dict['sub-001']['test_stim_name']))
# Out:
# torch.Size([492, 512])
# torch.Size([492, 1, 237653])
# torch.Size([492, 833])
# 492
# 492
# torch.Size([246, 512])
# torch.Size([246, 1, 237653])
# torch.Size([246, 833])
# 246
# 246

# %%
import pandas as pd

def process_data(data_dict, key_suffix, features_key, genre_key, stim_name_key, fmri_key):
    # Create DataFrame for fMRI and stimulus names
    df = pd.DataFrame(data_dict[fmri_key], dtype=float)
    df['Stimulus'] = data_dict[stim_name_key]
    
    # Group by 'Stimulus' and calculate the mean for fMRI data
    fmri_avg = df.groupby('Stimulus').mean().reset_index()
    
    # Create DataFrame for audio features and stimulus names
    df_features = pd.DataFrame(data_dict[features_key], dtype=float)
    df_features['Stimulus'] = data_dict[stim_name_key]
    
    # Group by 'Stimulus' and calculate the mean for audio features
    features_avg = df_features.groupby('Stimulus').mean().reset_index()
    
    # Handle genres (assuming genre data is aligned with stimuli names)
    df_genre = pd.DataFrame(data_dict[genre_key], columns=['Genre'])
    df_genre['Stimulus'] = data_dict[stim_name_key]
    
    # Since genre should be consistent for the same stimulus, we can take the first occurrence
    genre_avg = df_genre.groupby('Stimulus').first().reset_index()
    
    return {
        key_suffix + '_audio_feat': features_avg.drop(columns='Stimulus').values,
        key_suffix + '_genre': genre_avg['Genre'].values,
        key_suffix + '_stim_name_avg': fmri_avg['Stimulus'].values,
        key_suffix + '_fmri_avg': fmri_avg.drop(columns='Stimulus').values
    }

working_data_dict_avg={}
for sub in subject_ids:
    # Assuming working_data_dict is already defined and filled with your data
    working_data_dict_avg[sub]={}

    # Process training data
    working_data_dict_avg[sub].update(
        process_data(
            working_data_dict[sub],
            'train',
            'train_audio_feat',
            'train_genre',
            'train_stim_name',
            'train_fmri_avg'
        )
    )

    # Process testing data
    working_data_dict_avg[sub].update(
        process_data(
            working_data_dict[sub],
            'test',
            'test_audio_feat',
            'test_genre',
            'test_stim_name',
            'test_fmri_avg'
        )
    )

# %%
# Function to print dimensions and examples
def print_key_details(data_dict):
    for key, value in data_dict.items():
        # Print the dimensions of each item
        if isinstance(value, np.ndarray):
            print(f"Key: {key}, Dimensions: {value.shape}")
        else:
            print(f"Key: {key}, Type: {type(value)}")
        
        # Print some example data for genre and stimuli names
        if 'genre' in key or 'stim_name' in key:
            print(f"Example data for {key}: {value[:5]}")  # Print first 5 examples

for sub in subject_ids:
    # Assuming working_data_dict_avg is already populated and structured correctly
    print_key_details(working_data_dict_avg[sub])
# Out:
# Key: train_audio_feat, Dimensions: (480, 512)
# Key: train_genre, Dimensions: (480,)
# Example data for train_genre: ['blues' 'blues' 'blues' 'blues' 'blues']
# Key: train_stim_name_avg, Dimensions: (480,)
# Example data for train_stim_name_avg: ['/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00000.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00002.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00005.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00006.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00010.wav']
# Key: train_fmri_avg, Dimensions: (480, 833)
# Key: test_audio_feat, Dimensions: (60, 512)
# Key: test_genre, Dimensions: (60,)
# Example data for test_genre: ['blues' 'blues' 'blues' 'blues' 'blues']
# Key: test_stim_name_avg, Dimensions: (60,)
# Example data for test_stim_name_avg: ['/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00016.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00017.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00040.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00047.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00069.wav']
# Key: test_fmri_avg, Dimensions: (60, 833)
# Key: train_audio_feat, Dimensions: (480, 512)
# Key: train_genre, Dimensions: (480,)
# Example data for train_genre: ['blues' 'blues' 'blues' 'blues' 'blues']
# Key: train_stim_name_avg, Dimensions: (480,)
# Example data for train_stim_name_avg: ['/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00000.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00002.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00005.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00006.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00010.wav']
# Key: train_fmri_avg, Dimensions: (480, 833)
# Key: test_audio_feat, Dimensions: (60, 512)
# Key: test_genre, Dimensions: (60,)
# Example data for test_genre: ['blues' 'blues' 'blues' 'blues' 'blues']
# Key: test_stim_name_avg, Dimensions: (60,)
# Example data for test_stim_name_avg: ['/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00016.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00017.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00040.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00047.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00069.wav']
# Key: test_fmri_avg, Dimensions: (60, 833)
# Key: train_audio_feat, Dimensions: (480, 512)
# Key: train_genre, Dimensions: (480,)
# Example data for train_genre: ['blues' 'blues' 'blues' 'blues' 'blues']
# Key: train_stim_name_avg, Dimensions: (480,)
# Example data for train_stim_name_avg: ['/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00000.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00002.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00005.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00006.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00010.wav']
# Key: train_fmri_avg, Dimensions: (480, 833)
# Key: test_audio_feat, Dimensions: (60, 512)
# Key: test_genre, Dimensions: (60,)
# Example data for test_genre: ['blues' 'blues' 'blues' 'blues' 'blues']
# Key: test_stim_name_avg, Dimensions: (60,)
# Example data for test_stim_name_avg: ['/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00016.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00017.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00040.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00047.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00069.wav']
# Key: test_fmri_avg, Dimensions: (60, 833)
# Key: train_audio_feat, Dimensions: (480, 512)
# Key: train_genre, Dimensions: (480,)
# Example data for train_genre: ['blues' 'blues' 'blues' 'blues' 'blues']
# Key: train_stim_name_avg, Dimensions: (480,)
# Example data for train_stim_name_avg: ['/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00000.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00002.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00005.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00006.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00010.wav']
# Key: train_fmri_avg, Dimensions: (480, 833)
# Key: test_audio_feat, Dimensions: (60, 512)
# Key: test_genre, Dimensions: (60,)
# Example data for test_genre: ['blues' 'blues' 'blues' 'blues' 'blues']
# Key: test_stim_name_avg, Dimensions: (60,)
# Example data for test_stim_name_avg: ['/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00016.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00017.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00040.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00047.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00069.wav']
# Key: test_fmri_avg, Dimensions: (60, 833)
# Key: train_audio_feat, Dimensions: (480, 512)
# Key: train_genre, Dimensions: (480,)
# Example data for train_genre: ['blues' 'blues' 'blues' 'blues' 'blues']
# Key: train_stim_name_avg, Dimensions: (480,)
# Example data for train_stim_name_avg: ['/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00000.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00002.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00005.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00006.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00010.wav']
# Key: train_fmri_avg, Dimensions: (480, 833)
# Key: test_audio_feat, Dimensions: (60, 512)
# Key: test_genre, Dimensions: (60,)
# Example data for test_genre: ['blues' 'blues' 'blues' 'blues' 'blues']
# Key: test_stim_name_avg, Dimensions: (60,)
# Example data for test_stim_name_avg: ['/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00016.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00017.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00040.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00047.wav'
#  '/data01/data/fMRI_music_genre/data_wav/genres_original/blues/blues.00069.wav']
# Key: test_fmri_avg, Dimensions: (60, 833)

# %% [markdown]
# ## Reorder data

# %%
import pickle
import os


save_out_data=True

if save_out_data:
    # Ensure the 'data' directory exists
    if not os.path.exists('data'):
        os.makedirs('data')

    # Path to save the pickle file
    pickle_file_path = 'data/working_data_dict_avg.pkl'

    # Serialize and save the dictionary using pickle
    with open(pickle_file_path, 'wb') as file:
        pickle.dump(working_data_dict_avg, file)

    print(f'Data successfully saved to {pickle_file_path}')
    
else:
    # Path to the pickle file
    pickle_file_path = 'data/working_data_dict_avg.pkl'

    # Deserialize the dictionary from the pickle file
    with open(pickle_file_path, 'rb') as file:
        working_data_dict_avg = pickle.load(file)

    print('Data successfully loaded.')
    print(working_data_dict_avg)  # Optionally print or inspect some part of the loaded data
# Out:
# Data successfully saved to data/working_data_dict_avg.pkl

# %% [markdown]
# ## Functional Alignment

# %%
print(working_data_dict_avg['sub-001']['train_audio_feat'].shape)
print(working_data_dict_avg['sub-001']['train_fmri_avg'].shape)
print(working_data_dict_avg['sub-001']['train_genre'].shape)
print(working_data_dict_avg['sub-001']['train_stim_name_avg'].shape)
print(working_data_dict_avg['sub-001']['test_audio_feat'].shape)
print(working_data_dict_avg['sub-001']['test_fmri_avg'].shape)
print(working_data_dict_avg['sub-001']['test_genre'].shape)
print(working_data_dict_avg['sub-001']['test_stim_name_avg'].shape)
# Out:
# (480, 512)
# (480, 833)
# (480,)
# (480,)
# (60, 512)
# (60, 833)
# (60,)
# (60,)

# %%
## align on subject

# %%
target_sub="sub-001"

# X_train_aligned = [working_data_dict_avg[source_sub]["train_fmri_avg"]]
# X_test_aligned  = [working_data_dict_avg[source_sub]["test_fmri_avg"]]
X_train_aligned = []
X_test_aligned  = []


for source_sub in subject_ids:

    print(source_sub)
    source_train=working_data_dict_avg[source_sub]["train_fmri_avg"]
    target_train=working_data_dict_avg[target_sub]["train_fmri_avg"]

    source_test=working_data_dict_avg[source_sub]["test_fmri_avg"]
    target_test=working_data_dict_avg[target_sub]["test_fmri_avg"]


    source = Brain_Data()
    target = Brain_Data()

    # Load real data into Brain_Data instances
    source.data = source_train # Replace with actual source data
    target.data = target_train

    # Align source to target
    source_aligned = source.align(target)

    # Extract transformation matrix
    transformation_matrix = source_aligned["transformation_matrix"].data.T

    # Align and adjust source_train dataset
    aligned_source_train = source_train @ transformation_matrix
    aligned_source_train_adj = (aligned_source_train - aligned_source_train.mean(0)) / (1e-8 + aligned_source_train.std(0))
    aligned_source_train_adj = target.data.std(0) * aligned_source_train_adj + target.data.mean(0)

    # Align and adjust source_test dataset
    aligned_source_test = source_test @ transformation_matrix
    aligned_source_test_adj = (aligned_source_test - aligned_source_test.mean(0)) / (1e-8 + aligned_source_test.std(0))
    aligned_source_test_adj = target.data.std(0) * aligned_source_test_adj + target.data.mean(0)
    
    X_train_aligned.append(aligned_source_train_adj)
    X_test_aligned.append(aligned_source_test_adj)
    
#concatenate all

X_train_aligned = np.concatenate(X_train_aligned,0)
X_test_aligned = np.concatenate(X_test_aligned,0)

#concatenate all the other keys

train_audio_feat_aligned = np.concatenate([working_data_dict_avg[sub]["train_audio_feat"] for sub in subject_ids],0)
test_audio_feat_aligned = np.concatenate([working_data_dict_avg[sub]["test_audio_feat"] for sub in subject_ids],0)


train_genre_aligned = np.concatenate([working_data_dict_avg[sub]["train_genre"] for sub in subject_ids],0)
test_genre_aligned = np.concatenate([working_data_dict_avg[sub]["test_genre"] for sub in subject_ids],0)

train_stim_name_avg_aligned = np.concatenate([working_data_dict_avg[sub]["train_stim_name_avg"] for sub in subject_ids],0)
test_stim_name_avg_aligned = np.concatenate([working_data_dict_avg[sub]["test_stim_name_avg"] for sub in subject_ids],0)
# Out:
# sub-001
# sub-002
# sub-003
# sub-004
# sub-005

# %% [markdown]
# ## align on common space

# %%
le=LabelEncoder()

train_genre_enc=le.fit_transform(train_genre_aligned)
test_genre_enc=le.transform(test_genre_aligned)

X_train=X_train_aligned.copy()
X_test=X_test_aligned.copy()


clf_genre = LogisticRegression(C=10,random_state=0).fit(X_train, train_genre_enc)


y_pred_genre = clf_genre.predict(X_test)

print(classification_report(test_genre_enc,y_pred_genre))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.34      0.37      0.35        30
#            1       0.69      0.90      0.78        30
#            2       0.33      0.37      0.35        30
#            3       0.35      0.30      0.32        30
#            4       0.61      0.77      0.68        30
#            5       0.64      0.60      0.62        30
#            6       0.46      0.43      0.45        30
#            7       0.54      0.73      0.62        30
#            8       0.52      0.40      0.45        30
#            9       0.08      0.03      0.05        30
#
#     accuracy                           0.49       300
#    macro avg       0.46      0.49      0.47       300
# weighted avg       0.46      0.49      0.47       300

# %% [markdown]
# ## Decoding: Feature Estimation

# %%
## train a Ridge regression between X_train and audio_features
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, normalize



## scale also output features

# pipe =  Pipeline([('scaler', StandardScaler()), ('ridge', RidgeCV(alphas=[1e-3,1e-2,0.1,1,10,1e2,1e3],cv=5))])

brain_to_latent=RidgeCV(alphas=[1e-2,0.1,1,2,5,8,10,15,20,50,1e2,1e3])
# brain_to_latent=Ridge(alpha=10)

brain_to_latent.fit(X_train, train_audio_feat_aligned)
# Out:
# RidgeCV(alphas=[0.01, 0.1, 1, 2, 5, 8, 10, 15, 20, 50, 100.0, 1000.0])

# %%
brain_to_latent.alpha_
# Out:
# 20.0

# %%
audio_feat_pred=brain_to_latent.predict(X_test)

# %%
from sklearn.neighbors import NearestNeighbors
nbrs = NearestNeighbors(n_neighbors=5, algorithm='ball_tree').fit(test_audio_feat_aligned[:60])

# %%
distances, top_indices = nbrs.kneighbors(audio_feat_pred)

# %%
top_indices.shape
# Out:
# (300, 5)

# %%
from scipy.stats import pearsonr

def identification_accuracy(P, T):
    n = P.shape[0]
    C = np.zeros((n, n))
    
    # Compute the correlation matrix
    for i in tqdm.trange(n):
        for j in range(n):
            C[i, j], _ = pearsonr(P[i], T[j])
    
    # Compute identification accuracy per prediction
    id_acc = np.zeros(n)
    for i in tqdm.trange(n):
        # Compare the self-correlation with other correlations in the row
        id_acc[i] = (C[i, i] >= C[i]).sum()  
        id_acc[i] = id_acc[i] / (n - 1)
    
    # Average identification accuracy
    overall_id_acc = np.mean(id_acc)
    
    return overall_id_acc

# %%
# ## identification acc
id_accs=[]
for i in range(5):

    id_acc=identification_accuracy(audio_feat_pred[60*i:60*(i+1)],test_audio_feat_aligned[60*i:60*(i+1)])
    id_accs.append(id_acc)
    # print(id_acc)
    
np.mean(id_accs), np.std(id_accs)
# Out:
# 100%|██████████| 60/60 [00:00<00:00, 328.52it/s]
# 100%|██████████| 60/60 [00:00<00:00, 213631.78it/s]
# 100%|██████████| 60/60 [00:00<00:00, 385.52it/s]
# 100%|██████████| 60/60 [00:00<00:00, 149263.49it/s]
# 100%|██████████| 60/60 [00:00<00:00, 374.77it/s]
# 100%|██████████| 60/60 [00:00<00:00, 216201.24it/s]
# 100%|██████████| 60/60 [00:00<00:00, 398.05it/s]
# 100%|██████████| 60/60 [00:00<00:00, 217885.92it/s]
# 100%|██████████| 60/60 [00:00<00:00, 398.07it/s]
# 100%|██████████| 60/60 [00:00<00:00, 221335.30it/s]
# (0.8829378531073446, 0.026444420035550645)

# %%
print(id_accs)
# Out:
# [0.9217514124293786, 0.8813559322033899, 0.8418079096045197, 0.8728813559322035, 0.8968926553672316]

# %%
retrieval={}
for subject in subject_ids:
    retrieval[subject]={"true":[working_data_dict_avg[subject]["test_stim_name_avg"][idx] for idx in range(60)],
                        "retrieved":[working_data_dict_avg[subject]["test_stim_name_avg"][top_indices[idx]] for idx in range(60)]
                       }

# %%
# Save the dictionary using pickle
with open('retrieval_data.pkl', 'wb') as file:
    pickle.dump(retrieval, file)

# %%
sub_idx=1
idx=2
print(test_genre_aligned[:60][idx])
print(test_genre_aligned[:60][top_indices[idx]])
ipd.Audio(working_data_dict_avg[f"sub-00{sub_idx}"]["test_stim_name_avg"][idx],rate=22500)


# train_stim_name_avg
# Out:
# blues
# ['disco' 'metal' 'metal' 'blues' 'rock']
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
working_data_dict_avg[f"sub-00{sub_idx}"]["test_stim_name_avg"][top_indices[idx]]
# Out:
# array(['/data01/data/fMRI_music_genre/data_wav/genres_original/reggae/reggae.00047.wav',
#        '/data01/data/fMRI_music_genre/data_wav/genres_original/disco/disco.00004.wav',
#        '/data01/data/fMRI_music_genre/data_wav/genres_original/rock/rock.00027.wav',
#        '/data01/data/fMRI_music_genre/data_wav/genres_original/reggae/reggae.00070.wav',
#        '/data01/data/fMRI_music_genre/data_wav/genres_original/disco/disco.00071.wav'],
#       dtype=object)

# %%
ipd.Audio(working_data_dict_avg[f"sub-00{sub_idx}"]["test_stim_name_avg"][top_indices[idx][-2]],rate=22500)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Figures

# %% [markdown]
# ### Feature representations

# %%
audio_feat_example=train_audio_feat_aligned[:480]
audio_genre_example=train_genre_aligned[:480]

# %%
# train_genre_aligned

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Run t-SNE to reduce dimensionality
tsne = TSNE(n_components=2, random_state=0)
audio_feat_reduced = tsne.fit_transform(audio_feat_example)

# %%
# Step 2: Plotting
plt.figure(figsize=(10, 8))

# Create a custom color palette
palette = sns.color_palette("husl", len(np.unique(audio_genre_example)))


# Create a scatter plot
sns.scatterplot(x=audio_feat_reduced[:, 0], y=audio_feat_reduced[:, 1], hue=audio_genre_example,
                palette=palette,style=audio_genre_example, s=60, edgecolor='w', alpha=0.7)

# Enhance aesthetics
plt.title('t-SNE Visualization of Audio Features', fontsize=16)
plt.xlabel('t-SNE Feature 1')
plt.ylabel('t-SNE Feature 2')
sns.despine()  # Remove top and right borders

# Add a legend outside the plot
plt.legend(title='Genre', bbox_to_anchor=(1.05, 1), loc=2)

plt.show()

# %% [markdown]
# ## Plot the mask

# %%
from nilearn import plotting

# %%
nib_mask=nib.load("mask_01.nii.gz")

# %%
display=plotting.plot_glass_brain(None,display_mode="lyrz", title="Music ROI")
display.add_contours(nib_mask,filled=True,colors="tab:red")

display.savefig('brain_roi.png',dpi=300)

# %%
nib_mask.get_fdata().sum()
# Out:
# 833.0

# %% [markdown]
# ## Ceiling performances

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report


clf_ceiling = LogisticRegression(C=50,random_state=42).fit(train_audio_feat_aligned, train_genre_aligned)


test_genre_pred_from_clap = clf_ceiling.predict(test_audio_feat_aligned)

print(classification_report(test_genre_aligned,test_genre_pred_from_clap))
# Out:
#               precision    recall  f1-score   support
#
#        blues       0.83      1.00      0.91        30
#    classical       1.00      0.90      0.95        30
#      country       0.96      0.77      0.85        30
#        disco       1.00      0.67      0.80        30
#       hiphop       1.00      0.83      0.91        30
#         jazz       0.91      1.00      0.95        30
#        metal       0.74      0.97      0.84        30
#          pop       1.00      1.00      1.00        30
#       reggae       0.93      0.83      0.88        30
#         rock       0.67      0.87      0.75        30
#
#     accuracy                           0.88       300
#    macro avg       0.90      0.88      0.88       300
# weighted avg       0.90      0.88      0.88       300

# %% [markdown]
# ## Direct classification from the brain

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report


clf_direct_brain = LogisticRegression(C=50,random_state=42).fit(X_train_aligned, train_genre_aligned)


test_genre_pred_from_brain = clf_direct_brain.predict(X_test_aligned)

print(classification_report(test_genre_aligned,test_genre_pred_from_brain))
# Out:
#               precision    recall  f1-score   support
#
#        blues       0.34      0.37      0.35        30
#    classical       0.69      0.90      0.78        30
#      country       0.31      0.33      0.32        30
#        disco       0.35      0.30      0.32        30
#       hiphop       0.59      0.77      0.67        30
#         jazz       0.64      0.60      0.62        30
#        metal       0.46      0.43      0.45        30
#          pop       0.54      0.73      0.62        30
#       reggae       0.52      0.40      0.45        30
#         rock       0.08      0.03      0.05        30
#
#     accuracy                           0.49       300
#    macro avg       0.45      0.49      0.46       300
# weighted avg       0.45      0.49      0.46       300

# %% [markdown]
# ## Genre classification from estiamted clap features from the brain
#
# Try to use the same model of the ceiling but with estiamted features

# %%
train_audio_feat_aligned.mean(), train_audio_feat_aligned.std(), audio_feat_pred.mean(), audio_feat_pred.std()
# Out:
# (-0.0005942661985135746,
#  0.044180970626801666,
#  -0.0005942661985135747,
#  0.04388565234408042)

# %%
test_genre_pred_from_estimated_brain = clf_ceiling.predict(audio_feat_pred)

print(classification_report(test_genre_aligned,test_genre_pred_from_estimated_brain))
# Out:
#               precision    recall  f1-score   support
#
#        blues       0.35      0.37      0.36        30
#    classical       0.74      0.67      0.70        30
#      country       0.29      0.33      0.31        30
#        disco       0.48      0.43      0.46        30
#       hiphop       0.66      0.63      0.64        30
#         jazz       0.58      0.47      0.52        30
#        metal       0.43      0.40      0.41        30
#          pop       0.51      0.63      0.57        30
#       reggae       0.35      0.47      0.40        30
#         rock       0.18      0.13      0.15        30
#
#     accuracy                           0.45       300
#    macro avg       0.46      0.45      0.45       300
# weighted avg       0.46      0.45      0.45       300

# %% [markdown]
# ## Nearest Neighbors

# %%
def extract_genre(path):
    # Extracts the genre part from the given file path.
    parts = path.split('/')
    for i, part in enumerate(parts):
        if part == 'genres_original' and i + 1 < len(parts):
            return parts[i + 1]
    return None

# %%
top_indices
# Out:
# array([[30,  7, 16,  6, 41],
#        [59, 41, 25,  2,  5],
#        [23, 40, 41,  2, 59],
#        ...,
#        [56, 57, 17, 16, 13],
#        [12, 44, 31, 18, 16],
#        [22, 23, 59,  2, 19]])

# %%
def calculate_retr_accuracy(test_paths,top_indices, top_k=1):
    test_genres = np.array([extract_genre(path) for path in test_paths])

    print(test_genres.shape, top_indices.shape)
    correct_count = 0
    for i, test_genre in enumerate(test_genres):
        # Get the top-k predictions from the neighbors
        predicted_genres = [test_genres[idx] for idx in top_indices[i][:top_k]]
        # Check if the actual genre is in the top-k predicted genres
        if test_genre in predicted_genres:
            correct_count += 1

    accuracy = correct_count / len(test_genres)
    return accuracy

# Using the function to compute Top-1 and Top-3 accuracy
top1_accuracy = calculate_retr_accuracy(test_stim_name_avg_aligned, top_indices, top_k=1)
top3_accuracy = calculate_retr_accuracy(test_stim_name_avg_aligned, top_indices, top_k=3)

print("Top-1 Accuracy:", top1_accuracy)
print("Top-3 Accuracy:", top3_accuracy)
# Out:
# (300,) (300, 5)
# (300,) (300, 5)
# Top-1 Accuracy: 0.47
# Top-3 Accuracy: 0.6733333333333333

# %%
knn_genre_predictions = test_genre_aligned[top_indices[:,0]]

# %%
print(classification_report(test_genre_aligned,knn_genre_predictions))
# Out:
#               precision    recall  f1-score   support
#
#        blues       0.33      0.30      0.32        30
#    classical       0.78      0.70      0.74        30
#      country       0.57      0.27      0.36        30
#        disco       0.25      0.33      0.29        30
#       hiphop       0.54      0.63      0.58        30
#         jazz       0.67      0.73      0.70        30
#        metal       0.44      0.37      0.40        30
#          pop       0.56      0.60      0.58        30
#       reggae       0.37      0.47      0.41        30
#         rock       0.31      0.30      0.31        30
#
#     accuracy                           0.47       300
#    macro avg       0.48      0.47      0.47       300
# weighted avg       0.48      0.47      0.47       300

# %%
# df_confusion=pd.DataFrame(confusion_matrix(test_genre_aligned,knn_genre_predictions), columns=set(test_genre_aligned))

# %%
# Compute the confusion matrix
cm = confusion_matrix(test_genre_aligned, knn_genre_predictions)

# Extract the unique labels
labels = np.unique(test_genre_aligned)

# Sort labels based on the diagonal values of the confusion matrix in descending order
sorted_indices = np.argsort(-np.diag(cm))
sorted_labels = labels[sorted_indices]

# Reorder the confusion matrix
sorted_cm = cm[:, sorted_indices][sorted_indices]

# Plot the sorted confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(sorted_cm, annot=False, cmap="viridis", fmt="g", xticklabels=sorted_labels, yticklabels=sorted_labels)
plt.title('Confusion Matrix with Diagonal Sorted')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
